# %% [markdown]
# <a href="https://colab.research.google.com/github/Fournierp/alfred/blob/streamlit/models/LSTM%20Vanilla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Market Data
#
# In this kernel, we will design and train the model we will use in our web app. We will develop a Long Short-Term Memory (LSTM) Neural Network and harness its capability to solve problems in time series. This model will take as input Closing Stock Prices of previous days and predict the next days Stock Prices.
#
# Most resources online showed how to train a LSTM model on a single company's historical stock market dataset. Yet I want a model I can use to predict prices for various companies on the Alfred web-app. So I will aggregate a lot of data on publicly traded companies and train a model that can capture live stock market patterns.

# %%
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %matplotlib inline

# %%
np.random.seed(512)

# %% [markdown]
# # Pre-Processing

# %%
# Get the same list of companies that can be studied on Alfred
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
headers = {'User-Agent': 'Mozilla/5.0'}
companies = pd.read_html(url, storage_options=headers)[1]
# For the sake of the Proof Of Concept, we will use fewer companies than that
companies = companies[['Symbol']][companies['GICS Sector'] == 'Information Technology'].to_numpy().flatten()

# %% [markdown]
# The first challenge posed to us is to format the data. The LSTM needs a window of historical data points and a window of target points. This function splits the data accordingly

# %%
# Select a random company for evaluation
index = int(np.random.random() * len(companies))
eval_company = companies[index]
companies = np.delete(companies, index)
eval_company
# Out:
# 'AMAT'

# %%
input_len = 30
output_len = 1


def split_data_prices_in_windows(price_data: np.ndarray) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    inputs = []
    outputs = []
    first_prices = []

    for i in range(input_len, len(price_data)):
        historical_prices = price_data[i - input_len : i].copy()
        # Normalize the historical prices with respect to the first price in the sequence
        norm_historical_prices = (historical_prices / historical_prices[0]) - 1
        inputs.append(np.array(norm_historical_prices))

        # Process the model's expected output sequence
        target_price = (price_data[i].copy() / historical_prices[0]) - 1
        outputs.append(np.array(target_price))
        first_prices.append(historical_prices[0])

    inputs = np.array(inputs)
    outputs = np.array(outputs)
    first_prices = np.array(first_prices)
    return inputs, outputs, first_prices

# %% [markdown]
# Let's download all this data and store it in an array.

# %%
company_stock_data = yf.download(companies[0], period='max')

close_idx = company_stock_data.columns.get_loc('Close')
full_set = company_stock_data.iloc[:, close_idx].to_numpy()

x_full, y_full, _ = split_data_prices_in_windows(full_set)
x_full = np.reshape(x_full, (x_full.shape[0], x_full.shape[1]))

# Randomly sample 80% for training
n_samples = x_full.shape[0]
indices = np.random.permutation(n_samples)
train_size = int(n_samples * 0.80)
train_indices = indices[:train_size]
test_indices = indices[train_size:]

x_train = x_full[train_indices]
y_train = y_full[train_indices]
x_test = x_full[test_indices]
y_test = y_full[test_indices]

for company in companies[1:]:
    company_stock_data = yf.download(company, period='max')
    full_company_stock_data = company_stock_data.iloc[:, close_idx].to_numpy()

    if len(full_company_stock_data) < input_len + 1:
        continue

    x_full_company, y_full_company, _ = split_data_prices_in_windows(full_company_stock_data)
    x_full_company = np.reshape(x_full_company, (x_full_company.shape[0], x_full_company.shape[1]))

    # Randomly sample 80% for training
    n_samples_company = x_full_company.shape[0]
    indices_company = np.random.permutation(n_samples_company)
    train_size_company = int(n_samples_company * 0.80)
    train_indices_company = indices_company[:train_size_company]
    test_indices_company = indices_company[train_size_company:]

    x_train_company = x_full_company[train_indices_company]
    y_train_company = y_full_company[train_indices_company]
    x_test_company = x_full_company[test_indices_company]
    y_test_company = y_full_company[test_indices_company]

    # Gather the data points into a single array
    x_train = np.concatenate((x_train, x_train_company))
    x_test = np.concatenate((x_test, x_test_company))
    y_train = np.concatenate((y_train, y_train_company))
    y_test = np.concatenate((y_test, y_test_company))
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %% [markdown]
# Now that we have numerous company's historical stock market data, let us process it to facilitate the learning of the LSTM. Given the different scales of the companies, their stocks have different values. Let's scale the data according to the MinMaxScaler: normalize the data between (0, 1) based on the the overall maximum and minimum prices of all companies.

# %%
# Scale the data
total_max = x_train.max()
total_min = x_train.min()

x_train = (x_train - total_min) / (total_max - total_min)
x_test = (x_test - total_min) / (total_max - total_min)
y_train = (y_train - total_min) / (total_max - total_min)
y_test = (y_test - total_min) / (total_max - total_min)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot a sample training example
sample_train_idx = 0
ax1.plot(x_train[sample_train_idx].flatten(), label='Input Sequence (30 days)', marker='o')
ax1.plot(
    input_len, y_train[sample_train_idx][0], 'r*', markersize=15, label=f'Target: {y_train[sample_train_idx][0]:.4f}'
)
ax1.set_title('Sample Training Example')
ax1.set_xlabel('Day')
ax1.set_ylabel('Normalized Price')
ax1.legend()

# Plot a sample test example
sample_test_idx = 0
ax2.plot(x_test[sample_test_idx].flatten(), label='Input Sequence (30 days)', marker='o')
ax2.plot(input_len, y_test[sample_test_idx][0], 'r*', markersize=15, label=f'Target: {y_test[sample_test_idx][0]:.4f}')
ax2.set_title('Sample Test Example')
ax2.set_xlabel('Day')
ax2.set_ylabel('Normalized Price')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.utils import shuffle

# Shuffle the train data to avoid bias due to the ordering of data.
x_train, y_train = shuffle(x_train, y_train)

# %%
# Reshape the data for the LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# # Model Design

# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-11-27 19:32:32.381387: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-27 19:32:32.390794: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 19:32:32.702826: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
class LossHistory(Callback):
    def __init__(self) -> None:
        self.loss = []
        self.val_loss = []

    def on_batch_end(self, epoch: int, logs=None) -> None:  # noqa: ANN001, ARG002
        if logs is None:
            logs = {}
        self.loss.append(logs.get('loss'))

    def on_epoch_end(self, epoch, logs=None) -> None:  # noqa: ANN001, ARG002
        if logs is None:
            logs = {}
        self.val_loss.append(logs.get('val_loss'))

# %%
def build_model(input_shape: tuple, output_shape: int, neurons: int, dropout: float) -> Model:
    x = Input(shape=input_shape)
    hidden = LSTM(neurons, return_sequences=True)(x)
    hidden = Dropout(dropout)(hidden)
    hidden = LSTM(neurons, return_sequences=True)(x)
    hidden = Dropout(dropout)(hidden)
    hidden = LSTM(neurons, return_sequences=True)(x)
    hidden = Dropout(dropout)(hidden)
    hidden = LSTM(neurons, return_sequences=False)(hidden)
    hidden = Dropout(dropout)(hidden)
    y = Dense(output_shape, activation='linear')(hidden)
    return Model(inputs=x, outputs=y)


model = build_model((input_len, 1), output_len, 50, 0.2)

optimizer = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

model.compile(optimizer=optimizer, metrics=['mse'], loss='mean_squared_error')
# Out:
# 2025-11-27 19:32:34.174006: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.evaluate(x_test, y_test)
# Out:
# 3163/3163 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0272 - mse: 0.0272
# [0.02715083211660385, 0.02715083211660385]

# %%
epoch_size = 10
batch_size = 32

# Callback function to graph losses
lh = LossHistory()

# Callback function to stopp when the validation loss stagnates
es = EarlyStopping(patience=3)

# %% [markdown]
# # Training

# %%
history = model.fit(
    x_train, y_train, validation_data=(x_test, y_test), epochs=epoch_size, batch_size=batch_size, callbacks=[lh, es]
)
# Out:
# Epoch 1/10
# 12646/12646 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 2.8219e-04 - mse: 2.8219e-04 - val_loss: 7.8826e-05 - val_mse: 7.8826e-05
# Epoch 2/10
# 12646/12646 ━━━━━━━━━━━━━━━━━━━━ 133s 11ms/step - loss: 7.1079e-05 - mse: 7.1079e-05 - val_loss: 4.9931e-05 - val_mse: 4.9931e-05
# Epoch 3/10
# 12646/12646 ━━━━━━━━━━━━━━━━━━━━ 147s 12ms/step - loss: 5.8754e-05 - mse: 5.8754e-05 - val_loss: 4.7563e-05 - val_mse: 4.7563e-05
# Epoch 4/10
# 12646/12646 ━━━━━━━━━━━━━━━━━━━━ 141s 11ms/step - loss: 5.7705e-05 - mse: 5.7705e-05 - val_loss: 4.7017e-05 - val_mse: 4.7017e-05
# Epoch 5/10
#  6574/12646 ━━━━━━━━━━━━━━━━━━━━ 1:02 10ms/step - loss: 5.7467e-05 - mse: 5.7467e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 history = model.fit(
# ...

# %% [markdown]
# # Evaluation

# %%
model.evaluate(x_test, y_test)
# Out:
# 3163/3163 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 4.8088e-05 - mse: 4.8088e-05
# [4.808788071386516e-05, 4.808788071386516e-05]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(16, 6))
ax1.plot(lh.loss)
ax1.set_title('Train Loss')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Batch')
ax2.plot(lh.val_loss)
ax2.set_title('Validation Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch');

# %% [markdown]
# ## Evaluate on unseen stock

# %%
price_data = yf.download(eval_company)
price_data.index.name = None
price_data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker            AMAT        AMAT        AMAT        AMAT     AMAT
# 1980-03-17    0.069169    0.071055    0.069169    0.069169  3600000
# 1980-03-18    0.067911    0.069797    0.067911    0.069169  3715200
# 1980-03-19    0.069169    0.071055    0.069169    0.069169  2016000
# 1980-03-20    0.070426    0.072313    0.070426    0.070426  3657600
# 1980-03-21    0.072941    0.074828    0.072941    0.072941  3024000
# ...                ...         ...         ...         ...      ...
# 2025-11-20  220.229996  240.759995  218.960007  238.789993  9264000
# 2025-11-21  224.009995  228.160004  215.500000  219.199997  8596800
# 2025-11-24  230.910004  233.199997  222.860001  222.860001  8806600
# 2025-11-25  242.460007  244.619995  233.139999  237.550003  8330300
# 2025-11-26  249.970001  252.660004  242.830002  242.830002  8789300
#
# ...

# %%
eval_set = price_data.iloc[:, close_idx].to_numpy().flatten()

x_eval, y_eval, first_prices_eval = split_data_prices_in_windows(eval_set)
x_eval = np.reshape(x_eval, (x_eval.shape[0], x_eval.shape[1]))

x_eval = (x_eval - total_min) / (total_max - total_min)
y_eval = (y_eval - total_min) / (total_max - total_min)
x_eval = np.reshape(x_eval, (x_eval.shape[0], x_eval.shape[1], 1))

# %%
predicted_stock_price = model.predict(x_eval).reshape(-1)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
# Scale back the predicted stock price to original values
# Step 1: Reverse the MinMaxScaler normalization
predicted_stock_price = predicted_stock_price * (total_max - total_min) + total_min

# Step 2: Reverse the relative normalization (undo the "/ first_price - 1" operation)
predicted_stock_price = (predicted_stock_price + 1) * first_prices_eval

# %%
import bokeh
import bokeh.io
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, HoverTool, RangeTool
from bokeh.plotting import figure  # , output_notebook, save, show

bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d5dd8a34-1468-450e-b983-7f789d6b1bc1">Loading BokehJS ...</span>
#     </div>

# %%
df1 = pd.DataFrame(eval_set, index=price_data.iloc[:, close_idx].index, columns=['Close'])
df2 = pd.DataFrame(predicted_stock_price, index=price_data.iloc[input_len:, close_idx].index, columns=['Close'])
df1['Date'] = pd.to_datetime(df1.index)
df2['Date'] = pd.to_datetime(df2.index)
dates1 = df1['Date']
dates2 = df2['Date']
source1 = ColumnDataSource(data={'date': dates1, 'close': df1['Close']})
source2 = ColumnDataSource(data={'date': dates2, 'close': df2['Close']})

p = figure(
    height=300,
    width=800,
    tools='xpan',
    toolbar_location=None,
    x_axis_type='datetime',
    x_axis_location='above',
    background_fill_color='#efefef',
    x_range=(dates1[dates1.index[-100]], dates1[dates1.index[-1]]),
)
tmp = p.x_range  # Store it before adding multiple lines
p.line('date', 'close', source=source1, legend_label='Real Stock Price', color='green')
p.line('date', 'close', source=source2, legend_label='Predicted Stock Price', color='blue')

p.yaxis.axis_label = 'Price'


hover_tool = HoverTool(
    tooltips=[
        ('date', '@date{%F}'),
        ('close', '$@{close}{%0.2f}'),  # use @{ } for field names with spaces
    ],
    formatters={
        '@date': 'datetime',  # use 'datetime' formatter for '@date' field
        '@{close}': 'printf',  # use 'printf' formatter for '@{adj close}' field
    },
)
p.add_tools(hover_tool)

TOOLS = 'pan,wheel_zoom,box_zoom,reset,save'

select = figure(
    title='Drag the middle and edges of the selection box to change the range above',
    height=130,
    width=800,
    y_range=p.y_range,
    tools=TOOLS,
    x_axis_type='datetime',
    y_axis_type=None,
    toolbar_location=None,
    background_fill_color='#efefef',
)

range_tool = RangeTool(x_range=tmp)
range_tool.overlay.fill_color = 'navy'
range_tool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source1)
select.ygrid.grid_line_color = None
select.add_tools(range_tool, hover_tool)

# output_notebook()  # noqa: ERA001
# show(column(p, select))  # noqa: ERA001
# save(column(p, select), filename="plots/lstm_next_price.html")  # noqa: ERA001
bokeh.plotting.show(column(p, select))
# Out:
#   <div id="feb4c928-9366-4194-a0d5-33bff6ec4529" data-root-id="p1137" style="display: contents;"></div>

# %%
from pathlib import Path

model_data = {
    'total_max': total_max,
    'total_min': total_min,
    'output_len': output_len,
    'input_len': input_len,
}

# Create the checkpoint directory if it doesn't exist
Path('checkpoint').mkdir(parents=True, exist_ok=True)

with Path('checkpoint/data_vanilla.txt').open('w') as outfile:
    json.dump(model_data, outfile)

# %%
# Save the model.
# serialize model to JSON
model_json = model.to_json()
with Path('checkpoint/lstm_vanilla.json').open('w') as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights('checkpoint/lstm_vanilla.weights.h5')

# %% [markdown]
# # Conclusion
#
# We can see on the image that the predicted prices match quite precisely the real prices. One concern I have is that predicted predicted proces seem to have a certain delay. The predicted price seem to accurately match the previous day's closing price rather than the current day. One concern I have is that our data normalization technique does not sufficiently scale stock prices of different calibers.
